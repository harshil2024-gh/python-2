# %%
import pandas as pd
dataset = pd.read_csv("bollywood.csv")
df=pd.DataFrame(dataset)
df
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
df.lead[df['lead']=="Vicky Kaushal"].count()
# Out:
# 2

# %%
dataset[dataset['lead']=="Vicky Kaushal"].shape[0] # return count
# Out:
# 2

# %%
df.lead[df['movie']=="Kaante"]
# Out:
# 1494    Amitabh Bachchan
# Name: lead, dtype: object

# %%
import pandas as pd
dataset1 = pd.read_csv("movies.csv")
df1=pd.DataFrame(dataset1)
df1
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df1.year_of_release[df1['year_of_release']==2019].count()
# Out:
# 75

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# number of movie release on 2019 and imdb_rating>=7
dataset1[(dataset1['year_of_release']==2019) & (dataset1['imdb_rating']>=7)].shape[0]
# Out:
# 27

# %%
# imdb_votes>20000 => show detail of orginal title, story,wiki_link
s=dataset1[(dataset1['imdb_votes']>20000)][['original_title','story','wiki_link']]
s
# Out:
#                          original_title  \
# 0              Uri: The Surgical Strike
# 11                            Gully Boy
# 36                          Kabir Singh
# 74                          Dil Bechara
# 88                            Padmaavat
# ...                                 ...
# 1490                             Devdas
# 1565        Kabhi Khushi Kabhie Gham...
# 1567  Lagaan: Once Upon a Time in India
# 1568  Lagaan: Once Upon a Time in India
# 1571                     Dil Chahta Hai
#
#                                                   story  \
# 0     Divided over five chapters  the film chronicle...
# 11    Gully Boy is a film about a 22-year-old boy "M...
# 36    This Sandeep Vanga directorial is a remake of ...
# 74              A love story about two cancer patients.
# 88    This fictional story is set in 13th century me...
# ...                                                 ...
# 1490  Devdas Mukherji is black-listed by his multi-m...
# ...

# %%
e=dataset1[dataset1['year_of_release']==2019]
e=e.reset_index(drop=True)
ee=e['original_title']
print(ee)
# Out:
# 0          Uri: The Surgical Strike
# 1                     Battalion 609
# 2     The Accidental Prime Minister
# 3                   Why Cheat India
# 4                     Fraud Saiyyan
#                   ...
# 70                       Commando 3
# 71                       Mardaani 2
# 72                        Dabangg 3
# 73                       Good Newwz
# 74                            Daaka
# Name: original_title, Length: 75, dtype: object

# %%
import numpy as np
arr=np.array(ee)
print(arr)
# Out:
# ['Uri: The Surgical Strike' 'Battalion 609'
#  'The Accidental Prime Minister' 'Why Cheat India' 'Fraud Saiyyan'
#  'Bombairiya' 'Manikarnika: The Queen of Jhansi' 'Thackeray' 'Amavas'
#  'Gully Boy' 'Hum chaar' 'Total Dhamaal' 'Sonchiriya' 'Badla' 'Photograph'
#  'Risknamaa' '22 Yards' 'Kesari' 'Notebook' 'Junglee' 'Gone Kesh'
#  'Albert Pinto Ko Gussa Kyun Aata Hai?' 'The Tashkent Files' 'Kalank'
#  'Setters' 'Student of the Year 2' 'PM Narendra Modi' 'De De Pyaar De'
#  "India's Most Wanted" 'Khamoshi' 'Kabir Singh' 'Article 15'
#  'One Day: Justice Delivered' 'Hume Tumse Pyaar Kitna' 'Super 30'
#  'Family of Thakurganj' 'Batla House' 'Jhootha Kahin Ka'
#  'Judgementall Hai Kya' 'Chicken Curry Law' 'Arjun Patiala'
#  'Jabariya Jodi' 'Pranaam' 'The Sky Is Pink' 'Mission Mangal' 'Saaho'
#  'Dream Girl' 'Section 375' 'The Zoya Factor' 'Pal Pal Dil Ke Paas'
#  'Prassthanam' 'P Se Pyaar F Se Faraar' 'Ghost' 'Bala' '#Yaaram'
# ...

# %%
j=0
for i in arr:
    print(i," : ",e['release_date'][j])
    j=j+1
# Out:
# Uri: The Surgical Strike  :  11 January 2019 (USA)
# Battalion 609  :  11 January 2019 (India)
# The Accidental Prime Minister  :  11 January 2019 (USA)
# Why Cheat India  :  18 January 2019 (USA)
# Fraud Saiyyan  :  18 January 2019 (India)
# Bombairiya  :  18 January 2019 (India)
# Manikarnika: The Queen of Jhansi  :  25 January 2019 (USA)
# Thackeray  :  25 January 2019 (India)
# Amavas  :  8 February 2019 (India)
# Gully Boy  :  14 February 2019 (USA)
# Hum chaar  :  15 February 2019 (India)
# Total Dhamaal  :  22 February 2019 (India)
# Sonchiriya  :  1 March 2019 (India)
# Badla  :  8 March 2019 (India)
# Photograph  :  17 May 2019 (USA)
# Risknamaa  :  15 March 2019 (India)
# 22 Yards  :  15 March 2019 (India)
# Kesari  :  21 March 2019 (USA)
# Notebook  :  29 March 2019 (USA)
# Junglee  :  29 March 2019 (USA)
# Gone Kesh  :  29 March 2019 (India)
# Albert Pinto Ko Gussa Kyun Aata Hai?  :  12 April 2019 (India)
# The Tashkent Files  :  12 April 2019 (India)
# ...

# %%
k=pd.read_csv('kohli_ipl.csv',index_col="match_no",squeeze=True)

# %%
k=k.sort_values(ascending=True)
print(k.head(10))
# Out:
# match_no
# 87     0
# 211    0
# 207    0
# 206    0
# 91     0
# 93     0
# 8      0
# 130    0
# 135    0
# 106    1
# Name: runs, dtype: int64

# %%
k=k.sort_values(ascending=True)
k
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64

# %%
k[(k.values>90) & (k.values<100)]
# Out:
# match_no
# 145    92
# 81     93
# 82     99
# Name: runs, dtype: int64

# %%
import pandas as pd
dataset2 = pd.read_csv("ipl-matches.csv")
df2=pd.DataFrame(dataset1)
df2
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# how many matches gone into super over
dataset2[dataset2['SuperOver']=="Y"].shape[0]
# Out:
# 14

# %%
# how many matches won by toss winner matches
dataset2[dataset2['TossWinner']==dataset2['WinningTeam']].shape[0]
# Out:
# 489

# %%
#how many matches won by csk at kolkta
dataset2[(dataset2['WinningTeam']=="Chennai Super Kings") & (dataset2['City']=='Kolkata')].shape[0]
# Out:
# 5

# %%
#in how many matches hardik pandya is player of match vs RR
dataset2[(dataset2['Player_of_Match']=="HH Pandya") & ((dataset2['Team1']=='Rajasthan Royals') | (dataset2['Team2']=='Rajasthan Royals') )].shape[0]
# Out:
# 2

# %%
#in how matches GT won the toss and selected to bat and won the match
dataset2[(dataset2['TossWinner']=="Gujarat Titans") & (dataset2['TossDecision']=='bat') & (dataset2['WinningTeam']=='Gujarat Titans')].shape[0]
# Out:
# 2

# %%
#how many matches GT played
dataset2[(dataset2['Team1']=='Gujarat Titans') | (dataset2['Team2']=='Gujarat Titans')].shape[0]
# Out:
# 16

# %%
#how many matches won by GT in super over
dataset2[(dataset2['WinningTeam']=='Gujarat Titans') & (dataset2['SuperOver']=='Y')].shape[0]
# Out:
# 0

# %%
dataset2['WinningTeam'].value_counts()
# Out:
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Gujarat Titans                  12
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: WinningTeam, dtype: int64
